# %%
import numpy as np
import pandas as pd
import numba as nb
import matplotlib.pyplot as plt
import time

from IDT_alg_VR_centred import IDTVR

# %%
df_et = pd.read_csv("Data/eyetracking.txt", sep=";")

print("Shape", df_et.shape)
print("Columns", df_et.columns)
df_et.head(8)
# Out:
# Shape (2574, 16)
# Columns Index(['elapsedTime', 'nombre', 'et_x', 'et_y', 'et_z', 'et_pixel_uv_x',
#        'et_pixel_uv_y', 'head_pose_x', 'head_pose_y', 'head_pose_z',
#        'head_euler_x', 'head_euler_y', 'head_euler_z', 'head_quat_xyzw',
#        'Eye_Right_Blink', 'Eye_Left_Blink'],
#       dtype='object')
#    elapsedTime                                             nombre   et_x  \
# 0        0.023  Scene/Paneles_Numericos/EPVR_Ele_CuboConLuces/... -2.969
# 1        0.034  Scene/Paneles_Numericos/EPVR_Ele_CuboConLuces/... -2.969
# 2        0.048  Scene/Paneles_Numericos/EPVR_Ele_CuboConLuces/... -2.969
# 3        0.070  Scene/Paneles_Numericos/EPVR_Ele_CuboConLuces/... -2.969
# 4        0.092  Scene/Paneles_Numericos/EPVR_Ele_CuboConLuces/... -2.969
# 5        0.115  Scene/Paneles_Numericos/EPVR_Ele_CuboConLuces/... -2.969
# 6        0.139  Scene/Paneles_Numericos/EPVR_Ele_CuboConLuces/... -2.969
# 7        0.159  Scene/Paneles_Numericos/EPVR_Ele_CuboConLuces/... -2.969
#
#      et_y    et_z  et_pixel_uv_x  et_pixel_uv_y  head_pose_x  head_pose_y  \
# 0  1.5818 -1.1777       0.578985       0.600461      -0.4149       1.6291
# 1  1.5823 -1.1784       0.578571       0.600723      -0.4151       1.6289
# 2  1.5816 -1.1777       0.579005       0.600349      -0.4153       1.6288
# 3  1.5798 -1.1786       0.578443       0.599271      -0.4156       1.6288
# 4  1.5815 -1.1756       0.580233       0.600255      -0.4159       1.6288
# 5  1.5806 -1.1767       0.579583       0.599731      -0.4162       1.6287
# 6  1.5845 -1.1755       0.580342       0.602077      -0.4165       1.6287
# 7  1.5816 -1.1776       0.579050       0.600303      -0.4166       1.6287
#
#    head_pose_z  head_euler_x  head_euler_y  head_euler_z  \
# 0      -1.2984        5.9192      269.0828        0.8249
# 1      -1.2984        5.9479      269.0463        0.8471
# 2      -1.2984        5.9778      269.0420        0.8650
# 3      -1.2985        6.0055      269.0371        0.8853
# 4      -1.2985        6.0035      269.0070        0.9309
# 5      -1.2986        6.0344      268.9858        0.9401
# 6      -1.2986        6.0380      268.9710        0.9319
# 7      -1.2986        6.0123      268.9588        0.9102
#
#                   head_quat_xyzw  Eye_Right_Blink  Eye_Left_Blink
# 0  (.0311, -.7120, .0418, .7002)              0.0             0.0
# 1  (.0311, -.7123, .0422, .7000)              0.0             0.0
# 2  (.0312, -.7123, .0425, .6999)              0.0             0.0
# 3  (.0312, -.7123, .0428, .6999)              0.0             0.0
# 4  (.0309, -.7125, .0430, .6997)              0.0             0.0
# 5  (.0310, -.7126, .0433, .6995)              0.0             0.0
# 6  (.0311, -.7127, .0433, .6994)              0.0             0.0
# 7  (.0311, -.7128, .0430, .6994)              0.0             0.0

# %%
df_et = pd.read_csv(
    "C://Users/tbswe/data/et-data/VR/Logfiles_All/GazeData/p001_gazelog_on_machine_GFK-VR_date2017.6.14_time8.49.52.csv",
    skiprows=15,
    sep=";",
    encoding="utf-8",
)

df_et[["head_pose_x", "head_pose_y", "head_pose_z"]] = df_et[
    "head_pos"
].str.split(",", expand=True)
df_et[["et_x", "et_y", "et_z"]] = df_et["bino_hitObject_pos"].str.split(
    ",", expand=True
)
firstTimestamp = df_et.loc[0, "#timestamp_unity"]
df_et["elapsedTime"] = df_et["#timestamp_unity"] - firstTimestamp
print("Shape", df_et.shape)
print("Columns", df_et.columns)
df_et.head(8)
# Out:
# Shape (45883, 43)
# Columns Index(['#timestamp_unity', 'timestamp_smi', 'head_pos', 'head_dir',
#        'smi_bino_por', 'smi_left_por', 'smi_left_base', 'smi_left_dir',
#        'smi_right_por', 'smi_right_base', 'smi_right_dir',
#        'bino_gazePos_global', 'bino_hitObject', 'bino_gazePos_local',
#        'bino_hitObject_pos', 'bino_hitObject_dir', 'bino_hitObject_scl',
#        'bino_hitObject_TexCoord', 'bino_hitObject_Feature',
#        'left_gazePos_global', 'left_hitObject', 'left_gazePos_local',
#        'left_hitObject_pos', 'left_hitObject_dir', 'left_hitObject_scl',
#        'left_hitObject_TexCoord', 'left_hitObject_Feature',
#        'right_gazePos_global', 'right_hitObject', 'right_gazePos_local',
#        'right_hitObject_pos', 'right_hitObject_dir', 'right_hitObject_scl',
#        'right_hitObject_TexCoord', 'right_hitObject_Feature', 'Unnamed: 35',
#        'head_pose_x', 'head_pose_y', 'head_pose_z', 'et_x', 'et_y', 'et_z',
#        'elapsedTime'],
#       dtype='object')
#    #timestamp_unity  timestamp_smi                       head_pos  \
# 0          1186.836   1.234381e+12    -1.31369,1.77953,-0.6532125
# 1          1187.170   1.243201e+12  -1.289178,1.767716,-0.6821822
# 2          1187.503   1.243209e+12  -1.340189,1.761135,-0.6955911
# 3          1187.511   1.243218e+12   -1.33947,1.760692,-0.6950987
# 4          1187.522   1.243242e+12  -1.337413,1.759235,-0.6935291
# 5          1187.545   1.243265e+12  -1.335713,1.757644,-0.6921561
# 6          1187.567   1.243273e+12  -1.335517,1.757422,-0.6921113
# 7          1187.578   1.243289e+12  -1.334649,1.756655,-0.6913705
#
#                       head_dir       smi_bino_por       smi_left_por  \
# 0     2.24284,79.3271,5.289413   1061.494,646.725    1039.435,649.41
# 1   10.17717,103.0916,358.2414  1101.536,811.8827  1072.272,806.0854
# 2  12.74784,137.9351,0.5791597  1099.333,812.0182  1070.997,805.8777
# 3   12.85189,137.479,0.3577516   1097.746,812.194  1070.126,805.8381
# 4    13.40208,136.1206,359.791  1099.942,811.7125  1073.047,807.2813
# 5   14.15824,135.0944,359.6538   1037.824,810.369  1016.023,802.5681
# 6   14.28801,135.0624,359.7637  1024.759,805.1152   997.149,798.1165
# 7   14.66247,134.6094,359.7735  1019.526,802.3407  996.0416,791.1038
#
#                           smi_left_base                      smi_left_dir  \
# 0  -0.03316501,0.0005038494,-0.03630815   -0.01179717,-0.1173718,0.993018
# 1   -0.03301297,0.001528281,-0.03567222  0.007515335,-0.4412687,0.8973435
# 2    -0.03304359,0.001476976,-0.0356314  0.006419565,-0.4463517,0.8948346
# 3   -0.03305491,0.001403628,-0.03551621  0.008930573,-0.4458749,0.8950508
# 4    -0.03313671,0.00128562,-0.03564808   0.01993912,-0.4464585,0.8945822
# 5   -0.03300181,0.001087183,-0.03563282  -0.06141639,-0.4217822,0.9046147
# 6   -0.03296184,0.001041947,-0.03553583  -0.08337206,-0.4126913,0.9070474
# 7    -0.03294502,0.00119712,-0.03608138  -0.07116397,-0.4120487,0.9083785
#
#        smi_right_por                        smi_right_base  ...  \
# 0  1083.553,644.0402   0.02889526,-0.001987986,-0.03259998  ...
# 1  1130.799,817.6799  0.02854932,-0.0007540563,-0.03147267  ...
# 2  1127.669,818.1587  0.02854932,-0.0007540563,-0.03147267  ...
# 3  1125.366,818.5497  0.02854932,-0.0007540563,-0.03147267  ...
# 4  1126.837,816.1439    0.0284521,-0.001061178,-0.03142802  ...
# 5  1059.624,818.1699  0.02859335,-0.0008502628,-0.03071016  ...
# 6   1052.369,812.114   0.0285535,-0.0009895682,-0.03074798  ...
# 7  1043.011,813.5777  0.02857602,-0.0008649386,-0.02931023  ...
#
#   right_hitObject_TexCoord right_hitObject_Feature Unnamed: 35 head_pose_x  \
# 0                      NaN                     NaN         NaN    -1.31369
# 1                      NaN                     NaN         NaN   -1.289178
# 2                      NaN                     NaN         NaN   -1.340189
# 3                      NaN                     NaN         NaN    -1.33947
# 4                      NaN                     NaN         NaN   -1.337413
# 5                      NaN                     NaN         NaN   -1.335713
# 6                      NaN                     NaN         NaN   -1.335517
# 7                      NaN                     NaN         NaN   -1.334649
#
#   head_pose_y head_pose_z        et_x        et_y         et_z elapsedTime
# 0     1.77953  -0.6532125   0.3730002  -0.9300001  -0.09417015       0.000
# 1    1.767716  -0.6821822   0.3730002  -0.9300001  -0.09417015       0.334
# 2    1.761135  -0.6955911  0.02799988      0.7062    -1.062701       0.667
# 3    1.760692  -0.6950987  -0.4064397   0.6755455    -1.539988       0.675
# 4    1.759235  -0.6935291  -0.4064397   0.6755455    -1.539988       0.686
# 5    1.757644  -0.6921561  -0.4064397   0.6755455    -1.539988       0.709
# 6    1.757422  -0.6921113  -0.4064397   0.6755455    -1.539988       0.731
# 7    1.756655  -0.6913705  -0.4064397   0.6755455    -1.539988       0.742
#
# [8 rows x 43 columns]

# %%
df_et = df_et[
    [
        "head_pose_x",
        "head_pose_y",
        "head_pose_z",
        "et_x",
        "et_y",
        "et_z",
        "elapsedTime",
        "bino_hitObject",
        "bino_hitObject_Feature",
    ]
]
# cast the first columns to float (except the last 3)
df_et[df_et.columns[:-3]] = df_et[df_et.columns[:-3]].astype(float)
print("Shape", df_et.shape)
print("Columns", df_et.columns)
df_et.head(8)
# Out:
# Shape (45883, 9)
# Columns Index(['head_pose_x', 'head_pose_y', 'head_pose_z', 'et_x', 'et_y', 'et_z',
#        'elapsedTime', 'bino_hitObject', 'bino_hitObject_Feature'],
#       dtype='object')
#    head_pose_x  head_pose_y  head_pose_z     et_x      et_y      et_z  \
# 0    -1.313690     1.779530    -0.653212  0.37300 -0.930000 -0.094170
# 1    -1.289178     1.767716    -0.682182  0.37300 -0.930000 -0.094170
# 2    -1.340189     1.761135    -0.695591  0.02800  0.706200 -1.062701
# 3    -1.339470     1.760692    -0.695099 -0.40644  0.675546 -1.539988
# 4    -1.337413     1.759235    -0.693529 -0.40644  0.675546 -1.539988
# 5    -1.335713     1.757644    -0.692156 -0.40644  0.675546 -1.539988
# 6    -1.335517     1.757422    -0.692111 -0.40644  0.675546 -1.539988
# 7    -1.334649     1.756655    -0.691370 -0.40644  0.675546 -1.539988
#
#    elapsedTime             bino_hitObject bino_hitObject_Feature
# 0        0.000           other,Wand vorne                    NaN
# 1        0.334           other,Wand vorne                    NaN
# 2        0.667         102,Bauck Cupcakes                    NaN
# 3        0.675  other,Einkaufswagen_Vorne                    NaN
# 4        0.686  other,Einkaufswagen_Vorne                    NaN
# 5        0.709  other,Einkaufswagen_Vorne                    NaN
# 6        0.731  other,Einkaufswagen_Vorne                    NaN
# 7        0.742  other,Einkaufswagen_Vorne                    NaN

# %%
idt_vr = IDTVR(numba_allow=True)

t0 = time.time()
df_et_res = idt_vr.fit_compute(df_et, time="elapsedTime", debug=True)
delta_time_numba = time.time() - t0

print("Shape", df_et_res.shape)
print("Columns", df_et_res.columns)
# Out:
# [######################################..........................................] 22099/45882

# %%
df_et.isna().sum().sum()

# %%
print(
    "Percentage of fixations detected",
    np.round(100 * np.mean(df_et_res["class_disp"] == 0), 2),
    "%",
)
print(
    "Percentage of saccades detected",
    np.round(100 * np.mean(df_et_res["class_disp"] == 1), 2),
    "%",
)
print("Delta time", np.round(delta_time_numba, 4), "s")

# %%
idt_vr = IDTVR(numba_allow=False)

t0 = time.time()
df_et_res = idt_vr.fit_compute(df_et, time="elapsedTime")
delta_time_normal = time.time() - t0

print("Shape", df_et_res.shape)
print("Columns", df_et_res.columns)

# %%
print(
    "Percentage of fixations detected",
    np.round(100 * np.mean(df_et_res["class_disp"] == 0), 2),
    "%",
)
print(
    "Percentage of saccades detected",
    np.round(100 * np.mean(df_et_res["class_disp"] == 1), 2),
    "%",
)
print("Delta time", np.round(delta_time_normal, 4), "s")
